# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from datetime import datetime

# Example: Convert "2023-01-01 08:00:00" to Unix timestamp
past_time = datetime(2019, 1, 7, 8, 0)  # Year, Month, Day, Hour, Minute
unix_timestamp = int(past_time.timestamp())


# Google Maps Distance Matrix API setup
api_key = "AIzaSyCQLPvwaseF0cIS0efkoXp4kDW9RiwVJ9U"
base_url = "https://maps.googleapis.com/maps/api/distancematrix/json"

# Define parameters
params = {
    "origins": "Georgetown,CO",  # Starting location
    "destinations": "Silverthorn,CO",  # Destination location
    "mode": "driving",  # Travel mode
    "departure_time": ,  # 'now' for real-time data
    "key": api_key
}

# Send the API request
response = requests.get(base_url, params=params)

# Check the response
if response.status_code == 200:
    data = response.json()
    # Extract travel time and distance
    travel_time = data['rows'][0]['elements'][0]['duration']['text']
    distance = data['rows'][0]['elements'][0]['distance']['text']
    print(f"Travel time: {travel_time}")
    print(f"Distance: {distance}")
else:
    print(f"Error: {response.status_code}")
# Out:
# Error: 400
